# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/61.2 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 809.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 1.4 MB/s eta 0:00:08
#    ---------------------------------------- 0.0/10.6 MB 495.5 kB/s eta 0:00:22
#    ---------------------------------------- 0.1/10.6 MB 762.6 kB/s eta 0:00:14
#    ---------------------------------------- 0.1/10.6 MB 655.4 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/10.6 MB 654.9 kB/s eta 0:00:17
#     --------------------------------------- 0.2/10.6 MB 700.2 kB/s eta 0:00:15
#     --------------------------------------- 0.2/10.6 MB 655.9 kB/s eta 0:00:16
# ...

# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/160.4 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/160.4 kB 435.7 kB/s eta 0:00:01
#      ------- ----------------------------- 30.7/160.4 kB 435.7 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/160.4 kB 245.8 kB/s eta 0:00:01
#      ---------------- -------------------- 71.7/160.4 kB 326.8 kB/s eta 0:00:01
#      --------------------- --------------- 92.2/160.4 kB 374.1 kB/s eta 0:00:01
#      ------------------------- ---------- 112.6/160.4 kB 363.1 kB/s eta 0:00:01
#      --------------------------- -------- 122.9/160.4 kB 379.3 kB/s eta 0:00:01
#      -------------------------------- --- 143.4/160.4 kB 369.8 kB/s eta 0:00:01
#      ------------------------------------ 160.4/160.4 kB 368.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
crop_dataset = pd.read_csv("crop_npk_dataset_final.csv")
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
crop_dataset.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
crop_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
crop_dataset.shape
# Out:
# (2200, 8)

# %% [markdown]
# # Statistics

# %%
crop_dataset.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.8 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.8 kB 653.6 kB/s eta 0:00:01
#    ---------- ---------------------------- 81.9/294.8 kB 762.6 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.8 kB 944.1 kB/s eta 0:00:01
#    --------------------------------- ------ 245.8/294.8 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.8/294.8 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns

# %%
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
group_dataset = crop_dataset.groupby('label').describe()

# %%
group_dataset.head()
# Out:
#                N                                                            P  \
#            count    mean        std   min    25%    50%     75%    max  count
# label
# apple      100.0   20.80  11.863704   0.0  10.00   24.0   30.00   40.0  100.0
# banana     100.0  100.23  11.107241  80.0  92.00  100.5  108.25  120.0  100.0
# blackgram  100.0   40.02  12.664258  20.0  28.75   41.0   52.00   60.0  100.0
# chickpea   100.0   40.09  12.150649  20.0  30.00   39.0   52.00   60.0  100.0
# coconut    100.0   21.98  11.761931   0.0  13.75   24.0   31.00   40.0  100.0
#
#                    ...        ph           rainfall                         \
#              mean  ...       75%       max    count        mean        std
# label              ...
# apple      134.22  ...  6.135616  6.499227    100.0  112.654779   7.102985
# banana      82.01  ...  6.211092  6.490074    100.0  104.626980   9.398150
# blackgram   67.47  ...  7.419390  7.775306    100.0   67.884151   4.184186
# ...

# %%
corr = group_dataset.corr()

# %%
corr
# Out:
#                       N                                                    \
#                   count      mean       std       min       25%       50%
# N           count   NaN       NaN       NaN       NaN       NaN       NaN
#             mean    NaN  1.000000 -0.050479  0.999428  0.999560  0.999354
#             std     NaN -0.050479  1.000000 -0.049715 -0.070836 -0.055976
#             min     NaN  0.999428 -0.049715  1.000000  0.999175  0.997966
#             25%     NaN  0.999560 -0.070836  0.999175  1.000000  0.998812
#             50%     NaN  0.999354 -0.055976  0.997966  0.998812  1.000000
#             75%     NaN  0.999411 -0.025504  0.998793  0.998373  0.998526
#             max     NaN  0.999428 -0.050475  0.999968  0.999215  0.997996
# P           count   NaN       NaN       NaN       NaN       NaN       NaN
#             mean    NaN -0.248356 -0.112185 -0.256811 -0.248267 -0.240114
#             std     NaN -0.242874 -0.204824 -0.250418 -0.234112 -0.228499
# ...

# %%
crop_numeric = crop_dataset.drop('label',axis=1)

# %%
crop_numeric.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
corr = crop_numeric.corr()
corr
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# K           -0.053461
# temperature -0.030084
# humidity     0.094423
# ph          -0.109069
# rainfall     1.000000

# %% [markdown]
# # Corelation Matrix

# %%
sns.heatmap(corr,cbar=True,annot=True,cmap="crest")
# Out:
# <Axes: >

# %%
crop_dataset['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
crop_index = {
    'rice': 1,
    'maize': 2,
    'jute': 3,
    'cotton': 4,
    'coconut': 5,
    'papaya': 6,
    'orange': 7,
    'apple': 8,
    'muskmelon': 9,
    'watermelon': 10,
    'grapes': 11,
    'mango': 12,
    'banana': 13,
    'pomegranate': 14,
    'lentil': 15,
    'blackgram': 16,
    'mungbean': 17,
    'mothbeans': 18,
    'pigeonpeas': 19,
    'kidneybeans': 20,
    'chickpea': 21,
    'coffee': 22 
}

# %%
crop_dataset.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
crop_dataset['crop_index']= crop_dataset['label'].replace(crop_index)

# %%
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  crop_index
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice           1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice           1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice           1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice           1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice           1

# %%
crop_dataset.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label  \
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
#       crop_index
# 2195          22
# 2196          22
# 2197          22
# 2198          22
# 2199          22

# %% [markdown]
# # Splitting data

# %%
X = crop_dataset.drop(['label','crop_index'],axis=1)

# %%
X.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
Y= crop_dataset['crop_index']

# %%
Y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 2195    22
# 2196    22
# 2197    22
# 2198    22
# 2199    22
# Name: crop_index, Length: 2200, dtype: int64

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: crop_index, dtype: int64

# %%
Y.tail()
# Out:
# 2195    22
# 2196    22
# 2197    22
# 2198    22
# 2199    22
# Name: crop_index, dtype: int64

# %%
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  crop_index
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice           1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice           1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice           1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice           1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice           1

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      -------------------------------- ----- 51.2/60.4 kB 650.2 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 796.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.2 MB 3.2 MB/s eta 0:00:03
#     --------------------------------------- 0.1/9.2 MB 2.1 MB/s eta 0:00:05
#     --------------------------------------- 0.2/9.2 MB 2.1 MB/s eta 0:00:05
#     --------------------------------------- 0.2/9.2 MB 2.1 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/9.2 MB 1.3 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/9.2 MB 1.6 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/9.2 MB 1.7 MB/s eta 0:00:06
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,random_state=50,test_size=0.25)

# %%
x_train.head()
# Out:
#        N   P   K  temperature   humidity        ph    rainfall
# 959    3   9  45    23.891626  89.618502  6.535244  104.617522
# 538    4  47  20    25.979490  64.955854  4.193189   72.192458
# 1822   1   8  26    27.513630  94.189558  5.562912  156.673255
# 846    2  79  15    21.535779  65.472277  7.505284   35.751076
# 554   32  41  16    28.636189  61.394513  7.702287   68.548779

# %%
y_test.head()
# Out:
# 349     20
# 1546     8
# 1746     6
# 1640     7
# 772     16
# Name: crop_index, dtype: int64

# %% [markdown]
# # Scale

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
x_train=MinMaxScaler().fit_transform(x_train)

# %%
x_train
# Out:
# array([[0.02142857, 0.02857143, 0.2       , ..., 0.87910744, 0.47128032,
#         0.30286657],
#        [0.02857143, 0.3       , 0.075     , ..., 0.59140861, 0.10706074,
#         0.18631354],
#        [0.00714286, 0.02142857, 0.105     , ..., 0.93243049, 0.32007018,
#         0.48998272],
#        ...,
#        [0.76428571, 0.32857143, 0.085     , ..., 0.74614916, 0.38541107,
#         0.21282757],
#        [0.14285714, 0.88571429, 0.98      , ..., 0.90337876, 0.32395708,
#         0.34406091],
#        [0.31428571, 0.42142857, 0.245     , ..., 0.89966161, 0.50355002,
#         0.76328009]])

# %%
x_test = MinMaxScaler().fit_transform(x_test)

# %%
x_test
# Out:
# array([[0.06766917, 0.53956835, 0.07      , ..., 0.05021379, 0.40716381,
#         0.37702931],
#        [0.23308271, 0.89928058, 0.965     , ..., 0.91819698, 0.34126024,
#         0.35891726],
#        [0.26315789, 0.43884892, 0.21      , ..., 0.905649  , 0.57721456,
#         0.10290369],
#        ...,
#        [0.20300752, 0.12230216, 0.12      , ..., 0.91161061, 0.41640596,
#         0.45007265],
#        [0.45112782, 0.27338129, 0.195     , ..., 0.80370917, 0.65529252,
#         1.        ],
#        [0.30827068, 0.46043165, 0.385     , ..., 0.02753308, 0.5370876 ,
#         0.17529996]])

# %%
x_train= StandardScaler().fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.29085902, -1.33879704, -0.04867014, ...,  0.8215222 ,
#          0.09095658,  0.04166903],
#        [-1.26400918, -0.18343851, -0.54995436, ..., -0.28863136,
#         -3.00147077, -0.55234206],
#        [-1.34455871, -1.36920122, -0.42964615, ...,  1.02728171,
#         -1.1929018 ,  0.99530425],
#        ...,
#        [ 1.50152451, -0.06182182, -0.50985162, ...,  0.30847143,
#         -0.63812127, -0.41721366],
#        [-0.83441171,  2.30970361,  3.07934338, ...,  0.91517881,
#         -1.15989989,  0.25161551],
#        [-0.19001552,  0.33343242,  0.13179218, ...,  0.90083531,
#          0.36494435,  2.38816101]])

# %%
x_test = StandardScaler().fit_transform(x_test)

# %%
x_test
# Out:
# array([[-1.11546355,  0.7720542 , -0.59302812, ..., -2.37899094,
#         -0.64970654,  0.32700572],
#        [-0.50159586,  2.27708648,  2.79683535, ...,  0.93418468,
#         -1.12554544,  0.23682967],
#        [-0.38998355,  0.35064516, -0.06277015, ...,  0.88628783,
#          0.57809892, -1.03780754],
#        ...,
#        [-0.61320817, -0.97378325, -0.40365027, ...,  0.90904387,
#         -0.5829761 ,  0.69067303],
#        [ 0.30759337, -0.34166969, -0.1195835 , ...,  0.49717367,
#          1.14183976,  3.42864463],
#        [-0.22256509,  0.44094709,  0.60005232, ..., -2.46556539,
#          0.28837307, -0.67736188]])

# %% [markdown]
# # Training data using Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rc = RandomForestClassifier()

# %%
rc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
Yp = rc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,Yp)
# Out:
# 0.9854545454545455
