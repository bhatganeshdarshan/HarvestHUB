# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
crop_dataset = pd.read_csv("crop_npk_dataset_final.csv")
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
crop_dataset.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
crop_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
crop_dataset.shape
# Out:
# (2200, 8)

# %% [markdown]
# # Statistics

# %%
crop_dataset.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
import seaborn as sns

# %%
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
group_dataset = crop_dataset.groupby('label').describe()

# %%
group_dataset.head()
# Out:
#                N                                                            P  \
#            count    mean        std   min    25%    50%     75%    max  count
# label
# apple      100.0   20.80  11.863704   0.0  10.00   24.0   30.00   40.0  100.0
# banana     100.0  100.23  11.107241  80.0  92.00  100.5  108.25  120.0  100.0
# blackgram  100.0   40.02  12.664258  20.0  28.75   41.0   52.00   60.0  100.0
# chickpea   100.0   40.09  12.150649  20.0  30.00   39.0   52.00   60.0  100.0
# coconut    100.0   21.98  11.761931   0.0  13.75   24.0   31.00   40.0  100.0
#
#                    ...        ph           rainfall                         \
#              mean  ...       75%       max    count        mean        std
# label              ...
# apple      134.22  ...  6.135616  6.499227    100.0  112.654779   7.102985
# banana      82.01  ...  6.211092  6.490074    100.0  104.626980   9.398150
# blackgram   67.47  ...  7.419390  7.775306    100.0   67.884151   4.184186
# ...

# %%
corr = group_dataset.corr()

# %%
corr
# Out:
#                       N                                                    \
#                   count      mean       std       min       25%       50%
# N           count   NaN       NaN       NaN       NaN       NaN       NaN
#             mean    NaN  1.000000 -0.050479  0.999428  0.999560  0.999354
#             std     NaN -0.050479  1.000000 -0.049715 -0.070836 -0.055976
#             min     NaN  0.999428 -0.049715  1.000000  0.999175  0.997966
#             25%     NaN  0.999560 -0.070836  0.999175  1.000000  0.998812
#             50%     NaN  0.999354 -0.055976  0.997966  0.998812  1.000000
#             75%     NaN  0.999411 -0.025504  0.998793  0.998373  0.998526
#             max     NaN  0.999428 -0.050475  0.999968  0.999215  0.997996
# P           count   NaN       NaN       NaN       NaN       NaN       NaN
#             mean    NaN -0.248356 -0.112185 -0.256811 -0.248267 -0.240114
#             std     NaN -0.242874 -0.204824 -0.250418 -0.234112 -0.228499
# ...

# %%
crop_numeric = crop_dataset.drop('label',axis=1)

# %%
crop_numeric.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
corr = crop_numeric.corr()
corr
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# K           -0.053461
# temperature -0.030084
# humidity     0.094423
# ph          -0.109069
# rainfall     1.000000

# %% [markdown]
# # Corelation Matrix

# %%
sns.heatmap(corr,cbar=True,annot=True,cmap="crest")
# Out:
# <Axes: >

# %%
crop_dataset['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
crop_index = {
    'rice': 1,
    'maize': 2,
    'jute': 3,
    'cotton': 4,
    'coconut': 5,
    'papaya': 6,
    'orange': 7,
    'apple': 8,
    'muskmelon': 9,
    'watermelon': 10,
    'grapes': 11,
    'mango': 12,
    'banana': 13,
    'pomegranate': 14,
    'lentil': 15,
    'blackgram': 16,
    'mungbean': 17,
    'mothbeans': 18,
    'pigeonpeas': 19,
    'kidneybeans': 20,
    'chickpea': 21,
    'coffee': 22 
}

# %%
crop_dataset.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
crop_dataset['crop_index']= crop_dataset['label'].replace(crop_index)

# %%
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  crop_index
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice           1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice           1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice           1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice           1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice           1

# %%
crop_dataset.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label  \
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
#       crop_index
# 2195          22
# 2196          22
# 2197          22
# 2198          22
# 2199          22

# %% [markdown]
# # Splitting data

# %%
X = crop_dataset.drop(['label','crop_index'],axis=1)

# %%
X.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
Y= crop_dataset['crop_index']

# %%
Y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 2195    22
# 2196    22
# 2197    22
# 2198    22
# 2199    22
# Name: crop_index, Length: 2200, dtype: int64

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: crop_index, dtype: int64

# %%
Y.tail()
# Out:
# 2195    22
# 2196    22
# 2197    22
# 2198    22
# 2199    22
# Name: crop_index, dtype: int64

# %%
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  crop_index
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice           1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice           1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice           1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice           1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice           1

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,random_state=50,test_size=0.25)

# %%
x_train.head()
# Out:
#        N   P   K  temperature   humidity        ph    rainfall
# 959    3   9  45    23.891626  89.618502  6.535244  104.617522
# 538    4  47  20    25.979490  64.955854  4.193189   72.192458
# 1822   1   8  26    27.513630  94.189558  5.562912  156.673255
# 846    2  79  15    21.535779  65.472277  7.505284   35.751076
# 554   32  41  16    28.636189  61.394513  7.702287   68.548779

# %%
y_test.head()
# Out:
# 349     20
# 1546     8
# 1746     6
# 1640     7
# 772     16
# Name: crop_index, dtype: int64

# %% [markdown]
# # Scale

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
# x_train=MinMaxScaler().fit_transform(x_train)

# %%
# x_train

# %%
# x_test = MinMaxScaler().fit_transform(x_test)

# %%
# x_test

# %%
# sc=StandardScaler()
# sc.fit(x_train)
# x_train = sc.transform(x_train)
# x_test = sc.transform(x_test)

# %%
# x_train

# %%
# x_test

# %% [markdown]
# # Training data using Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rc = RandomForestClassifier()

# %%
rc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
Yp = rc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_test,Yp)
# Out:
# 0.9945454545454545

# %%
cm = confusion_matrix(y_test,Yp)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=rc.classes_, yticklabels=rc.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import classification_report
classification_report(y_test, Yp)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      0.90      0.95        30\n           2       1.00      1.00      1.00        20\n           3       0.92      1.00      0.96        36\n           4       1.00      1.00      1.00        25\n           5       1.00      1.00      1.00        28\n           6       1.00      1.00      1.00        31\n           7       1.00      1.00      1.00        29\n           8       1.00      1.00      1.00        26\n           9       1.00      1.00      1.00        18\n          10       1.00      1.00      1.00        23\n          11       1.00      1.00      1.00        30\n          12       1.00      1.00      1.00        23\n          13       1.00      1.00      1.00        16\n          14       1.00      1.00      1.00        20\n          15       1.00      1.00      1.00        27\n          16       1.00      1.00      1.00        22\n          17       1.00      1.00      1.00        20\n     
# ...

# %%
print(classification_report(y_test,Yp))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.90      0.95        30
#            2       1.00      1.00      1.00        20
#            3       0.92      1.00      0.96        36
#            4       1.00      1.00      1.00        25
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        31
#            7       1.00      1.00      1.00        29
#            8       1.00      1.00      1.00        26
#            9       1.00      1.00      1.00        18
#           10       1.00      1.00      1.00        23
#           11       1.00      1.00      1.00        30
#           12       1.00      1.00      1.00        23
#           13       1.00      1.00      1.00        16
#           14       1.00      1.00      1.00        20
#           15       1.00      1.00      1.00        27
#           16       1.00      1.00      1.00        22
# ...

# %% [markdown]
# # Prediction with given parameters

# %%
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  crop_index
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice           1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice           1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice           1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice           1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice           1

# %%
def predict_crop(n, p, k, temp, hum, ph, rainfall):
    parameters = np.array([[n, p, k, temp, hum, ph, rainfall]])
    p = rc.predict(parameters).reshape(-1, 1)
    return p[0, 0]

# %%
crop_index
# Out:
# {'rice': 1,
#  'maize': 2,
#  'jute': 3,
#  'cotton': 4,
#  'coconut': 5,
#  'papaya': 6,
#  'orange': 7,
#  'apple': 8,
#  'muskmelon': 9,
#  'watermelon': 10,
#  'grapes': 11,
#  'mango': 12,
#  'banana': 13,
#  'pomegranate': 14,
#  'lentil': 15,
#  'blackgram': 16,
#  'mungbean': 17,
#  'mothbeans': 18,
#  'pigeonpeas': 19,
#  'kidneybeans': 20,
#  'chickpea': 21,
#  'coffee': 22}

# %%
crop_index_swap = {val: key for key, val in crop_index.items()}

# %%
crop_index_swap
# Out:
# {1: 'rice',
#  2: 'maize',
#  3: 'jute',
#  4: 'cotton',
#  5: 'coconut',
#  6: 'papaya',
#  7: 'orange',
#  8: 'apple',
#  9: 'muskmelon',
#  10: 'watermelon',
#  11: 'grapes',
#  12: 'mango',
#  13: 'banana',
#  14: 'pomegranate',
#  15: 'lentil',
#  16: 'blackgram',
#  17: 'mungbean',
#  18: 'mothbeans',
#  19: 'pigeonpeas',
#  20: 'kidneybeans',
#  21: 'chickpea',
#  22: 'coffee'}

# %%
crop_dataset.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# crop_index       int64
# dtype: object

# %%
crop_dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  crop_index
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice           1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice           1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice           1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice           1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice           1

# %%
crop_param=crop_dataset.drop(['label','crop_index'],axis=1)
crop_param.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
crop_param.columns.tolist()
# Out:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# %%
features_data = {'columns':list(crop_param.columns)}
features_data
# Out:
# {'columns': ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']}

# %%
test_series = pd.Series(np.zeros(len(features_data['columns'])),index=features_data['columns'])
test_series
# Out:
# N              0.0
# P              0.0
# K              0.0
# temperature    0.0
# humidity       0.0
# ph             0.0
# rainfall       0.0
# dtype: float64

# %%
test_series['N'] = 16
test_series['P'] = 29
test_series['K'] = 13
test_series['temperature'] = 32.319
test_series['humidity'] = 93.67
test_series['ph'] = 6.19
test_series['rainfall'] = 117.62

test_series
# Out:
# N               16.000
# P               29.000
# K               13.000
# temperature     32.319
# humidity        93.670
# ph               6.190
# rainfall       117.620
# dtype: float64

# %%
new_rf_model = rscv_model.best_estimator_

y_pred = new_rf_model.predict(x_test)

# %%
from sklearn.model_selection import RandomizedSearchCV
rf = RandomForestClassifier()
param_grid = {'n_estimators':np.arange(50,200),
    'criterion':['gini','entropy'],
    'max_depth':np.arange(2,25),
    'min_samples_split':np.arange(2,25),
    'min_samples_leaf':np.arange(2,25)}

rscv_model = RandomizedSearchCV(rf,param_grid, cv=5)
rscv_model.fit(x_train,y_train)
rscv_model.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=5, min_samples_split=16,
#                        n_estimators=143)

# %%
output = new_rf_model.predict([test_series])[0]
output
# Out:
# C:\Users\bhatg\miniconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 7
